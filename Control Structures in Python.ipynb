# %%
temperature = 30

if temperature > 25:
    print("its hot")
else:
    print("its cold")
# Out:
# its hot

# %%
#underage
age = 23

if age < 18:
    print("you are under age")
    print("you can't drink alcohol")
    print("you can't get married")
    print("you can't have ID")
    print("you can drive in Kenya")
    print("====================")
else:
    print("you can do all above")
# Out:
# you can do all above

# %%
#multiple conditon - elseif

monthly_income = 0

if monthly_income <= 5000:
    print("Low income")
elif monthly_income <= 15000:
    print("Middle class")
else:
    print("High income")
# Out:
# Low income

# %%
# assign A, B, C, D, E for over 80 , above 70 ,60, 50,and below 50 reapective

mark = 70

if mark >= 80:
    print("A")
elif mark >= 70:
    print("B")
elif mark >= 60:
    print("C")
elif mark >= 50:
    print("D")
else:
    print("E")
# Out:
# B
